# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import seaborn as sns
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 4E2B-C9C8
#
#  Directory of C:\Users\gmzyn\++++++€ALI�MALAR
#
# 19.12.2022  23:53    <DIR>          .
# 19.12.2022  23:07    <DIR>          ..
# 19.12.2022  23:47    <DIR>          .ipynb_checkpoints
# 19.12.2022  23:53            16.557 2015.csv
# 18.12.2022  00:12    <DIR>          bluebook-for-bulldozers
# 18.12.2022  00:12    <DIR>          Functions
# 18.12.2022  00:12    <DIR>          Jose_Matplotlib
# 18.12.2022  00:12    <DIR>          jose_pandas
# 18.12.2022  00:12    <DIR>          Loops-D”ng�ler
# 18.12.2022  00:12    <DIR>          Numpy
# 18.12.2022  00:12    <DIR>          Product-Analytics
# 18.12.2022  00:12    <DIR>          sampions_lig
# 18.12.2022  00:12    <DIR>          scout_car_proje
# 19.12.2022  23:48             2.272 World Happiness Report.ipynb
#                2 File(s)         18.829 bytes
#               12 Dir(s)  326.915.629.056 bytes free

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '2015.csv', 'bluebook-for-bulldozers', 'Functions', 'Jose_Matplotlib', 'jose_pandas', 'Loops-Döngüler', 'Numpy', 'Product-Analytics', 'sampions_lig', 'scout_car_proje', 'World Happiness Report.ipynb']

# %%
# Number of rows of file to read. Useful for reading pieces of large files.

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
df1 = pd.read_csv('2015.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = '2015.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 158 rows and 12 columns

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
plt.figure(figsize=(12,8))
sns.countplot(df1['Region']);
plt.xticks(rotation=60)
plt.show()

# %%
df1.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df1.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df1['Country'].unique()
# Out:
# array(['Switzerland', 'Iceland', 'Denmark', 'Norway', 'Canada', 'Finland',
#        'Netherlands', 'Sweden', 'New Zealand', 'Australia', 'Israel',
#        'Costa Rica', 'Austria', 'Mexico', 'United States', 'Brazil',
#        'Luxembourg', 'Ireland', 'Belgium', 'United Arab Emirates',
#        'United Kingdom', 'Oman', 'Venezuela', 'Singapore', 'Panama',
#        'Germany', 'Chile', 'Qatar', 'France', 'Argentina',
#        'Czech Republic', 'Uruguay', 'Colombia', 'Thailand',
#        'Saudi Arabia', 'Spain', 'Malta', 'Taiwan', 'Kuwait', 'Suriname',
#        'Trinidad and Tobago', 'El Salvador', 'Guatemala', 'Uzbekistan',
#        'Slovakia', 'Japan', 'South Korea', 'Ecuador', 'Bahrain', 'Italy',
#        'Bolivia', 'Moldova', 'Paraguay', 'Kazakhstan', 'Slovenia',
#        'Lithuania', 'Nicaragua', 'Peru', 'Belarus', 'Poland', 'Malaysia',
#        'Croatia', 'Libya', 'Russia', 'Jamaica', 'North Cyprus', 'Cyprus',
# ...

# %%
len(df1['Country'].unique())
# Out:
# 158

# %%
# En mutlu 10 ülke
sns.barplot(y = df1["Country"][:10], x = df["Happiness Score"][:10])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Country'>

# %%
#En mutsuz 10 ülke
sns.barplot(y = df1["Country"][-10:], x = df1["Happiness Score"][-10:])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Country'>

# %%
#2015 yılında turkıye 76. sırada
df1_turkiye = df1[df1["Country"]=="Turkey"]

# %%
df1_turkiye
# Out:
#    Country                           Region  Happiness Rank  Happiness Score  \
# 75  Turkey  Middle East and Northern Africa              76            5.332
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 75         0.03864                   1.06098  0.94632
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 75                   0.73172  0.22815                        0.15746
#
#     Generosity  Dystopia Residual
# 75     0.12253            2.08528

# %%
list_features 'Health (Life Expectancy)'
# Out:
# ['Health (Life Expectancy)']

# %%
list_features=['Health (Life Expectancy)']
sns.boxplot(data=df1.loc[:,list_features],orient='v', palette='Set3')
# Out:
# <AxesSubplot:>

# %%
list_features=['Health (Life Expectancy)']
sns.boxplot(data=df1['Health (Life Expectancy)'],orient='v', palette='Set3')
# Out:
# <AxesSubplot:>

# %% [raw]
# Happiest and Unhappiest Countries in 2015

# %%
df1.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
sns.histplot(data=df1,x='Happiness Score',bins=20)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Count'>

# %%
sns.scatterplot(data=df1)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df1,x='Happiness Score',y=df1["Country"][:20],)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Country'>

# %%
df1_happiest_unhappiest=df1[(df1.loc[:,'Happiness Score']>7.4)| (df1.loc[:,'Happiness Score']<3.5)]
sns.barplot(x='Happiness Score', y='Country',data=df1_happiest_unhappiest,palette='coolwarm')
plt.show()

# %%
df2_happiest_unhappiest=df2[(df2.loc[:,'Happiness Score']>7.4)| (df2.loc[:,'Happiness Score']<3.5)]
sns.barplot(x='Happiness Score', y='Country',data=df2_happiest_unhappiest,palette='coolwarm')
plt.show()

# %%
sns.countplot(df1["Region"])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
df1.plot(kind="box",figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
df1.drop('Happiness Rank',axis=1).plot(kind="box",figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df1['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)'>

# %%
df1['Trust (Government Corruption)'].describe()
# Out:
# count    158.000000
# mean       0.143422
# std        0.120034
# min        0.000000
# 25%        0.061675
# 50%        0.107220
# 75%        0.180255
# max        0.551910
# Name: Trust (Government Corruption), dtype: float64

# %%
sns.pairplot(df1,hue='Happiness Score')

# %%
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
plt.style.use('seaborn-notebook')

# %%
df1

# %% [markdown]
# Generous Distribution by Regional Indicator

# %%
sns.swarmplot(x='Region',y='Generosity',data=df1)
plt.xticks(rotation=60)
plt.title('Generous Distribution by Regional Indicator')
plt.show()

# %%
sns.swarmplot(x='Region',y='Happiness Score',data=df1)
plt.xticks(rotation=60)
plt.title('Generous Distribution by Regional Indicator')
plt.show()

# %%
df1.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 4E2B-C9C8
#
#  Directory of C:\Users\gmzyn\++++++€ALI�MALAR
#
# 20.12.2022  09:00    <DIR>           (2).ipynb_checkpoints
# 20.12.2022  09:00    <DIR>          .
# 19.12.2022  23:07    <DIR>          ..
# 19.12.2022  23:47    <DIR>          .ipynb_checkpoints
# 19.12.2022  23:53            16.557 2015.csv
# 20.12.2022  08:48            17.132 2016.csv
# 20.12.2022  08:49            29.536 2017.csv
# 18.12.2022  00:12    <DIR>          bluebook-for-bulldozers
# 18.12.2022  00:12    <DIR>          Functions
# 18.12.2022  00:12    <DIR>          Jose_Matplotlib
# 18.12.2022  00:12    <DIR>          jose_pandas
# 18.12.2022  00:12    <DIR>          Loops-D”ng�ler
# 18.12.2022  00:12    <DIR>          Numpy
# 18.12.2022  00:12    <DIR>          Product-Analytics
# 18.12.2022  00:12    <DIR>          sampions_lig
# 18.12.2022  00:12    <DIR>          scout_car_proje
# 20.12.2022  01:40           233.571 World Happiness Report.ipynb
# ...

# %%
df2=pd.read_csv("2016.csv")

# %%
df2
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
plt.figure(figsize=(12,8))
sns.countplot(df2['Region']);
plt.xticks(rotation=60)
plt.show()

# %%
df2_happiest_unhappiest=df2[(df2.loc[:,'Happiness Score']>7.4)| (df2.loc[:,'Happiness Score']<3.5)]
sns.barplot(x='Happiness Score', y='Country',data=df2_happiest_unhappiest,palette='coolwarm')
plt.show()

# %%
df3=pd.read_csv("2017.csv")

# %%
df3_happiest_unhappiest=df3[(df3.loc[:,'Happiness.Score']>7.3)| (df3.loc[:,'Happiness.Score']<3.5)]
sns.barplot(x='Happiness.Score', y='Country',data=df3_happiest_unhappiest,palette='coolwarm')
plt.show()

# %%
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
sort_df1
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
df3.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
sort_df1 = df1.head(10)
sort_df2 = df2.head(10)
sort_df3 = df3.head(10)
f, axs = plt.subplots(2,2, figsize = (14,14), constrained_layout = True)
ax=sns.barplot(x="Country", y="Happiness Score", data=sort_df1 , ax = axs[0, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness Score", data=sort_df2, ax = axs[1, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness.Score", data=sort_df3, ax = axs[1, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax.tick_params(axis = 'x', rotation = 45)
axs[0, 0].title.set_text('2015 YILI EN MUTLU 10 ULKE')
axs[1, 0].title.set_text('2016 YILI EN MUTLU 10 ULKE')
axs[1, 1].title.set_text('2017 YILI EN MUTLU 10 ULKE')

# %%
sns.pairplot(df1)

# %%
df1.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df1=df1.sort_values(by=['Country'])

# %%
df2=df2.sort_values(by=['Country'])

# %%
df3=df3.sort_values(by=['Country'])

# %%
df_allScore=pd.DataFrame(df1["Happiness Score"])

# %%
df1
# Out:
#          Country                           Region  Happiness Rank  \
# 152  Afghanistan                    Southern Asia             153
# 94       Albania       Central and Eastern Europe              95
# 67       Algeria  Middle East and Northern Africa              68
# 136       Angola               Sub-Saharan Africa             137
# 29     Argentina      Latin America and Caribbean              30
# ..           ...                              ...             ...
# 22     Venezuela      Latin America and Caribbean              23
# 74       Vietnam                Southeastern Asia              75
# 135        Yemen  Middle East and Northern Africa             136
# 84        Zambia               Sub-Saharan Africa              85
# 114     Zimbabwe               Sub-Saharan Africa             115
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 152            3.575         0.03084                   0.31982  0.30285
# ...

# %%
df_allScore.rename(columns={"Happiness Score":"Happiness_Score_15"},errors="raise",inplace=True)
df_allScore
# Out:
#      Happiness_Score_15
# 152               3.575
# 94                4.959
# 67                5.605
# 136               4.033
# 29                6.574
# ..                  ...
# 22                6.810
# 74                5.360
# 135               4.077
# 84                5.129
# 114               4.610
#
# [158 rows x 1 columns]

# %%
df_allScore["Happiness_Score_16"]=df2["Happiness Score"]

# %%
df1["Happiness Score"].head()
# Out:
# 152    3.575
# 94     4.959
# 67     5.605
# 136    4.033
# 29     6.574
# Name: Happiness Score, dtype: float64

# %%
df_allScore["Happiness_Score_17"]=df3["Happiness.Score"]

# %%
df3["Happiness.Score"]
# Out:
# 140    3.794
# 108    4.644
# 52     5.872
# 139    3.795
# 23     6.599
#        ...
# 81     5.250
# 93     5.074
# 145    3.593
# 115    4.514
# 137    3.875
# Name: Happiness.Score, Length: 155, dtype: float64

# %%
df_allScore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 152 to 114
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Happiness_Score_15  158 non-null    float64
#  1   Happiness_Score_16  157 non-null    float64
#  2   Happiness_Score_17  155 non-null    float64
# dtypes: float64(3)
# memory usage: 4.9 KB

# %%
df_allScore["Fark"]=df_allScore["Happiness_Score_17"]-df_allScore["Happiness_Score_15"]

# %%
df_allScore["Country"]=df1["Country"]

# %%
df_allScore["Happiness_Score_17"].isnull()
# Out:
# 152    False
# 94     False
# 67     False
# 136    False
# 29     False
#        ...
# 22     False
# 74     False
# 135    False
# 84     False
# 114    False
# Name: Happiness_Score_17, Length: 158, dtype: bool

# %%
df_allScore[df_allScore["Happiness_Score_17"].isnull()].index
# Out:
# Int64Index([21, 136, 141], dtype='int64')

# %%
df_allScore.drop(index=df_allScore[df_allScore["Happiness_Score_17"].isnull()].index,inplace=True)

# %%
df_allScore.reset_index(inplace=True)

# %%
df_allScore.isnull().any()
# Out:
# level_0               False
# index                 False
# Happiness_Score_15    False
# Happiness_Score_16    False
# Happiness_Score_17    False
# Fark                  False
# Country               False
# dtype: bool

# %%
df_allScore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   level_0             155 non-null    int64
#  1   index               155 non-null    int64
#  2   Happiness_Score_15  155 non-null    float64
#  3   Happiness_Score_16  155 non-null    float64
#  4   Happiness_Score_17  155 non-null    float64
#  5   Fark                155 non-null    float64
#  6   Country             155 non-null    object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 8.6+ KB

# %%
df_allScore.columns
# Out:
# Index(['level_0', 'index', 'Happiness_Score_15', 'Happiness_Score_16',
#        'Happiness_Score_17', 'Fark', 'Country'],
#       dtype='object')

# %%
del df_allScore['level_0']

# %%
del df_allScore['index']

# %%
df_allScore.columns
# Out:
# Index(['Happiness_Score_15', 'Happiness_Score_16', 'Happiness_Score_17',
#        'Fark', 'Country'],
#       dtype='object')

# %%
df_allScore[df_allScore["Fark"] <- 0.20]
# Out:
#      Happiness_Score_15  Happiness_Score_16  Happiness_Score_17   Fark  \
# 0                 3.575               3.484               3.349 -0.226
# 12                6.937               6.907               6.714 -0.223
# 13                3.340               3.303               2.693 -0.647
# 21                3.819               3.739               3.603 -0.216
# 46                3.896               3.832               3.657 -0.239
# 101               3.845               3.763               3.644 -0.201
# 105               6.853               6.739               6.635 -0.218
# 108               6.786               6.701               6.578 -0.208
# 117               3.465               3.360               2.905 -0.560
# 121               4.507               4.324               4.292 -0.215
# 145               6.901               6.871               6.652 -0.249
# 146               6.867               6.778               6.648 -0.219
# ...

# %%
df_allScore.describe()
# Out:
#        Happiness_Score_15  Happiness_Score_16  Happiness_Score_17        Fark
# count          155.000000          155.000000          155.000000  155.000000
# mean             5.423329            5.413090            5.354019   -0.069310
# std              1.102913            1.115702            1.131230    0.113198
# min              3.340000            3.303000            2.693000   -0.647000
# 25%              4.568000            4.437000            4.505500   -0.142500
# 50%              5.268000            5.389000            5.279000   -0.063000
# 75%              6.282000            6.296500            6.101500   -0.001000
# max              7.587000            7.526000            7.537000    0.162000

# %%
df_allScore[df_allScore.loc[:,'Fark'] <-0.20]["Fark"].round(3)
# Out:
# 0     -0.226
# 12    -0.223
# 13    -0.647
# 21    -0.216
# 46    -0.239
# 101   -0.201
# 105   -0.218
# 108   -0.208
# 117   -0.560
# 121   -0.215
# 145   -0.249
# 146   -0.219
# 150   -0.201
# Name: Fark, dtype: float64

# %%
plt.figure(figsize=(15,8))
df2_happiest_Fark=df_allScore[df_allScore.loc[:,'Fark'] <-0.20]["Fark"].round(3)
sns.barplot(x=df2_happiest_Fark ,y=df_allScore[df_allScore.loc[:,'Fark'] <-0.20]["Country"],fill='True',linewidth=2)
plt.show()

# %%
plt.figure(figsize=(15,8))
df2_happiest_Fark=df_allScore[df_allScore.loc[:10,'Fark'] ["Fark"].round(3)
sns.barplot(x=df2_happiest_Fark ,y=df_allScore[df_allScore.loc[:10,'Fark']]["Country"],fill='True',linewidth=2)
plt.show()
# Out:
#   Input In [437]
#     sns.barplot(x=df2_happiest_Fark ,y=df_allScore[df_allScore.loc[:10,'Fark']]["Country"],fill='True',linewidth=2)
#     ^
# SyntaxError: invalid syntax

# %%
df_allScore.loc[:10,'Fark'].round(3)
# Out:
# 0    -0.226
# 1     0.115
# 2    -0.080
# 3    -0.097
# 4    -0.122
# 5    -0.160
# 6    -0.000
# 7    -0.194
# 8     0.057
# 9     0.003
# 10   -0.050
# Name: Fark, dtype: float64

# %%
df_allScore.loc[10:20,'Fark'].round(3)
# Out:
# 10   -0.050
# 11    0.009
# 12   -0.223
# 13   -0.647
# 14    0.020
# 15    0.030
# 16    0.092
# 17   -0.152
# 18   -0.032
# 19   -0.186
# 20   -0.125
# Name: Fark, dtype: float64

# %%
df_allScore.loc[lambda df_allScore : df_allScore['Fark'] < -0.20]["Fark"]
# Out:
# 0     -0.226
# 12    -0.223
# 13    -0.647
# 21    -0.216
# 46    -0.239
# 101   -0.201
# 105   -0.218
# 108   -0.208
# 117   -0.560
# 121   -0.215
# 145   -0.249
# 146   -0.219
# 150   -0.201
# Name: Fark, dtype: float64

# %%
df_allScore
# Out:
#      Happiness_Score_15  Happiness_Score_16  Happiness_Score_17   Fark  \
# 0                 3.575               3.484               3.349 -0.226
# 1                 4.959               5.121               5.074  0.115
# 2                 5.605               5.560               5.525 -0.080
# 3                 4.033               3.974               3.936 -0.097
# 4                 6.574               6.488               6.452 -0.122
# ..                  ...                 ...                 ...    ...
# 150               6.810               6.725               6.609 -0.201
# 151               5.360               5.458               5.324 -0.036
# 152               4.077               4.028               3.970 -0.107
# 153               5.129               5.185               5.234  0.105
# 154               4.610               4.508               4.535 -0.075
#
#          Country
# 0    Afghanistan
# 1        Albania
# 2        Algeria
# 3         Angola
# 4      Argentina
# ...

# %%
df_allScore.Country
# Out:
# 0      Afghanistan
# 1          Albania
# 2          Algeria
# 3           Angola
# 4        Argentina
#           ...
# 150      Venezuela
# 151        Vietnam
# 152          Yemen
# 153         Zambia
# 154       Zimbabwe
# Name: Country, Length: 155, dtype: object

# %%
a=input('ulke ismini gir')
a=a.capitalize()
first_value = list(df_allScore[df_allScore.Country == a].values[0][0:3])
yıllar=list(df_allScore.columns[0:3])
sns.barplot( y=yıllar,x =first_value)
plt.title("{}'nin yıllara göre mutluluk skoru".format(a), size=15)
# Out:
# ulke ismini girZimbabwe
# Text(0.5, 1.0, "Zimbabwe'nin yıllara göre mutluluk skoru")

# %%
df_allScore[df_allScore["Country"]=="Turkey"]

# %%
df_allScore.columns[0:3]
# Out:
# Index(['Happiness_Score_15', 'Happiness_Score_16', 'Happiness_Score_17'], dtype='object')

# %%
fig=px.scatter(df1,
              x='Trust (Government Corruption)',
              y='Happiness Score',              
              animation_group= df1["Country"],
             
              template='plotly_dark',
              color='Region',
              hover_name='Country',
              size_max=60)
fig.update_layout(title='Trust (Government Corruption) and Happiness Score to Make Life Choices by Countries')
fig.show()
# Out:
# <div>                            <div id="9c599458-1884-44dc-9e25-3923039331c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c599458-1884-44dc-9e25-3923039331c9")) {                    Plotly.newPlot(                        "9c599458-1884-44dc-9e25-3923039331c9",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Region=Western Europe<br>Trust (Government Corruption)=%{x}<br>Happiness Score=%{y}<extra></extra>","hovertext":["Switzerland","Iceland","Denmark","Norway","Finland","Netherlands","Sweden","Austria","Luxembourg","Ireland","Belgium","United Kingdom","Germany","France","Spain","Malta","Italy","North Cyprus","Cyprus","Portugal","Greece"],"ids":["Switzerland","Iceland","Denmark","Norway","Finland","Netherlands","Sweden","A
# ...
